# %% [markdown]
# <a href="https://colab.research.google.com/github/pushpenderb/machine-learning/blob/main/Linear_regrssion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Sample dataset
X = np.array([[1], [2], [3], [4], [5]])  # sklearn expects 2D array
y = np.array([2, 4, 5, 4, 5])

# Create and train model
model = LinearRegression()
model.fit(X, y)

# Coefficients
print(f"Slope (m): {model.coef_[0]}")
print(f"Intercept (c): {model.intercept_}")

# Predictions
y_pred = model.predict(X)

# Plotting
plt.scatter(X, y, color="blue", label="Data points")
plt.plot(X, y_pred, color="red", label="Regression line")
plt.xlabel("X")
plt.ylabel("y")
plt.legend()
plt.show()
# Out:
# Slope (m): 0.6
# Intercept (c): 2.2
